# %%
pip install pymupdf
# Out:
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---- ----------------------------------- 2.4/19.2 MB 11.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.0/19.2 MB 11.6 MB/s eta 0:00:02
#    --------------- ------------------------ 7.3/19.2 MB 11.6 MB/s eta 0:00:02
#    -------------------- ------------------- 10.0/19.2 MB 11.5 MB/s eta 0:00:01
#    ------------------------- -------------- 12.3/19.2 MB 11.6 MB/s eta 0:00:01
#    ------------------------------ --------- 14.7/19.2 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.3/19.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 10.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdfminer.high_level import extract_text

text = extract_text("H:\AutoAttendance\Reportformat\Demo Report.pdf")

with open("output.txt", "w", encoding="utf-8") as f:
    f.write(text)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\A'
# <>:3: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2660\1187846041.py:3: SyntaxWarning: invalid escape sequence '\A'
#   text = extract_text("H:\AutoAttendance\Reportformat\Demo Report.pdf")
